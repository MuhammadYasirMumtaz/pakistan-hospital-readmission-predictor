# %%
import pymysql

# Test MySQL connection
try:
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password='admin123789',  # Replace with YOUR password you set during installation
        port=3306
    )
    print("MySQL connection successful!")
    connection.close()
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# MySQL connection successful!

# %%
import pymysql

connection = pymysql.connect(
    host='localhost',
    user='root',
    password='admin123789',
    port=3306
)

cursor = connection.cursor()

cursor.execute("CREATE DATABASE IF NOT EXISTS hospital_db")
cursor.execute("USE hospital_db")

cursor.execute("""
CREATE TABLE IF NOT EXISTS patients (
    id INT AUTO_INCREMENT PRIMARY KEY,
    race VARCHAR(50),
    gender VARCHAR(10),
    age VARCHAR(20),
    admission_type_id INT,
    discharge_disposition_id INT,
    admission_source_id INT,
    time_in_hospital INT,
    medical_specialty VARCHAR(100),
    num_lab_procedures INT,
    num_procedures INT,
    num_medications INT,
    number_outpatient INT,
    number_emergency INT,
    number_inpatient INT,
    number_diagnoses INT,
    max_glu_serum VARCHAR(20),
    A1Cresult VARCHAR(20),
    insulin VARCHAR(20),
    change_flag VARCHAR(10),
    diabetesMed VARCHAR(10),
    readmitted VARCHAR(10),
    readmitted_binary INT
)
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS predictions (
    id INT AUTO_INCREMENT PRIMARY KEY,
    prediction_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    time_in_hospital INT,
    num_medications INT,
    number_diagnoses INT,
    number_inpatient INT,
    num_lab_procedures INT,
    num_procedures INT,
    number_outpatient INT,
    number_emergency INT,
    risk_score FLOAT,
    risk_level VARCHAR(20),
    prediction_result INT
)
""")

connection.commit()
connection.close()

print("Database hospital_db created successfully!")
print("Tables created:")
print("  patients - stores all patient records")
print("  predictions - stores all ML predictions")
# Out:
# Database hospital_db created successfully!
# Tables created:
#   patients - stores all patient records
#   predictions - stores all ML predictions

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Load cleaned data
df_clean = pd.read_csv("../data/clean_data_readable.csv")

print(f"Loading {len(df_clean)} patients into MySQL...")

# Create SQLAlchemy engine
engine = create_engine('mysql+pymysql://root:admin123789@localhost:3306/hospital_db')

# Select only the columns that match our patients table
df_load = df_clean[[
    'race', 'gender', 'age', 'admission_type_id',
    'discharge_disposition_id', 'admission_source_id',
    'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
    'num_procedures', 'num_medications', 'number_outpatient',
    'number_emergency', 'number_inpatient', 'number_diagnoses',
    'max_glu_serum', 'A1Cresult', 'insulin', 'change',
    'diabetesMed', 'readmitted_binary'
]].copy()

# Rename change column to match our table
df_load = df_load.rename(columns={"change": "change_flag"})

# Load into MySQL
df_load.to_sql("patients", con=engine, if_exists="append", index=False)

print("Successfully loaded {len(df_load)} patients into MySQL!")
print("Database is Live!")
# Out:
# Loading 99493 patients into MySQL...
# Successfully loaded {len(df_load)} patients into MySQL!
# Database is Live!

# %%
# THIS CELL ONLY NEEDS TO RUN ONCE
# Table is already created correctly - skip this cell
print("Table already exists with correct column sizes - skipping!")
# Out:
# Table already exists with correct column sizes - skipping!

# %%
import pymysql

connection = pymysql.connect(
    host='localhost',
    user='root',
    password='admin123789',
    port=3306
)

cursor = connection.cursor()
cursor.execute("USE hospital_db")

# Count rows in patients table
cursor.execute("Select COUNT(*) FROM patients")
count = cursor.fetchone()[0]
print(f"Total patients in MySQL: {count}")

# Show first 3 rows
cursor.execute("SELECT id, race, gender, age, time_in_hospital, readmitted_binary FROM patients LIMIT 3" )
rows = cursor.fetchall()
print("\n Sample rows from database:")
for row in rows:
    print(row)

connection.close()
# Out:
# Total patients in MySQL: 99493
#
#  Sample rows from database:
# (1, 'Caucasian', 'Female', '[0-10)', 1, 0)
# (2, 'Caucasian', 'Female', '[10-20)', 3, 0)
# (3, 'AfricanAmerican', 'Female', '[20-30)', 2, 0)

# %%
print("=" * 50)
print("DAY 2 COMPLETE!")
print("=" * 50)
print("Databse: hospital_db")
print("Tables created:")
print(" patients   -99,493 rows loaded")
print(" prediction - ready for ML predictions")
print("\nMySQL Connection Details:")
print(" Host: localhost")
print(" Port: 3306")
print(" Database: hospital_db")
print(" User: root")
print("=" * 50)
print("Tomorrow - Day 3: XG Boost ML Model")
print("=" * 50)
# Out:
# ...
# DAY 2 COMPLETE!
# ...
# Databse: hospital_db
# Tables created:
#  patients   -99,493 rows loaded
#  prediction - ready for ML predictions
#
# MySQL Connection Details:
#  Host: localhost
#  Port: 3306
#  Database: hospital_db
#  User: root
# ...
# Tomorrow - Day 3: XG Boost ML Model
# ...

# %%
import pymysql

connection = pymysql.connect(
    host='localhost',
    user='root',
    password='admin123789',
    port=3306
)

cursor = connection.cursor()
cursor.execute("USE hospital_db")
cursor.execute("SELECT COUNT(*) FROM patients")
count = cursor.fetchone()[0]
print(f"Total patients in MySQL: {count}")
connection.close()
# Out:
# Total patients in MySQL: 99493
